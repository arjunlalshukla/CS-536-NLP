# %% [markdown]
# # Feedforward Network using Keras

# %%
# Package imports
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
import sklearn.linear_model
import matplotlib
import keras

# Display plots inline and change default figure size
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
# Generate a dataset and plot it
np.random.seed(0)
Xt, yt = sklearn.datasets.make_moons(200, noise=0.20)
print(Xt.shape, yt.shape)
plt.scatter(Xt[:,0], Xt[:,1], s=40, c=yt, cmap=plt.cm.Spectral)
# Out:
# (200, 2) (200,)

# %%
from keras.models import Model
from keras.layers import Input, Dense
from keras.models import Sequential

yt = keras.utils.to_categorical(yt, 2)

# %%
# define a model directly
a = Input(shape=(2,))
b = Dense(50)(a)
model = Model(inputs=a, outputs=b)

# %%
# define a model using Sequential
model = Sequential()
model.add(Dense(units=128, activation='relu', input_dim=2))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# %%
model.fit(Xt,yt, epochs=100, verbose=False)

# %%
score = model.evaluate(Xt, yt, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test score: 0.28441878080368044
# Test accuracy: 0.86
